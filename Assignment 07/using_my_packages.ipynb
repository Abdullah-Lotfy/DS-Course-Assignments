# %%
import my_packages.Transformers.StringTransformer as mts

# %%
mts.rev_string("Ahmed will arrive tomorrow")
# Out:
# 'worromot evirra lliw demhA'

# %%
mts.cap_string("Ahmed will arrive tomorrow")
# Out:
# 'AHMED WILL ARRIVE TOMORROW'

# %%
import my_packages.Operations.Math as om

# %%
om.get_average(2,3,4,6)
# Out:
# 3.75

# %%
om.get_average(2,3)
# Out:
# 2.5

# %%
om.get_average(2,3,4,5,6,7,8,9)
# Out:
# 5.5
